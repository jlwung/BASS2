# %%
import tensorflow as tf

def read_my_file_format(filename_queue):
    reader = tf.TextLineReader(skip_header_lines=1)
    key, value = reader.read(filename_queue)
    
    record_defaults = [[1] for i in range(541)]
#     print(record_defaults)

    cols = tf.decode_csv(value, record_defaults=record_defaults)
    labels = tf.one_hot(cols[1], 2)
    features = tf.stack(cols[2:])

    return features, labels

def input_pipeline(filenames, batch_size, num_epochs=None):
    filename_queue = tf.train.string_input_producer(
        filenames, num_epochs=num_epochs, shuffle=True)
    example, label = read_my_file_format(filename_queue)
  # min_after_dequeue defines how big a buffer we will randomly sample
  #   from -- bigger means better shuffling but slower start up and more
  #   memory used.
  # capacity must be larger than min_after_dequeue and the amount larger
  #   determines the maximum we will prefetch.  Recommendation:
  #   min_after_dequeue + (num_threads + a small safety margin) * batch_size
    min_after_dequeue = 10000
    capacity = min_after_dequeue + 3 * batch_size
    example_batch, label_batch = tf.train.shuffle_batch(
        [example, label], batch_size=batch_size, capacity=capacity,
        min_after_dequeue=min_after_dequeue)
    return example_batch, label_batch


train_features_app, train_labels_app = input_pipeline(["data/train_approved.csv"], 100)
train_features_rej, train_labels_rej = input_pipeline(["data/train_rejected.csv"], 100)
train_features = tf.concat([train_features_app, train_features_rej], 0)
train_labels = tf.concat([train_labels_app, train_labels_rej], 0)

# train_features, train_labels = input_pipeline(["data/train_approved.csv", "data/train_rejected.csv"], 100)

test_features, test_labels = input_pipeline(["data/test.csv"], 100)


init = tf.global_variables_initializer()

# with tf.Session() as sess:
#     sess.run(init)
    
#     coord = tf.train.Coordinator()
#     threads = tf.train.start_queue_runners(coord=coord)

#     print( sess.run([train_features, train_labels]) )
    
#     coord.request_stop()
#     coord.join(threads)
    
# print("\nEnd.\n")

# %%
#define place holder
x = tf.placeholder(tf.float32, [None, 539])
y = tf.placeholder(tf.float32, [None, 2])


#create a 3-level neural network
W1 = tf.Variable(tf.truncated_normal([539, 500]))
b1 = tf.Variable(tf.zeros([500])+0.1)
L1 = tf.nn.softmax(tf.matmul(x, W1)+b1)

W2 = tf.Variable(tf.truncated_normal([500, 300]))
b2 = tf.Variable(tf.zeros([300])+0.1)
L2 = tf.nn.softmax(tf.matmul(L1, W2)+b2)

W3 = tf.Variable(tf.truncated_normal([300, 2]))
b3 = tf.Variable(tf.zeros([2])+0.1)
prediction = tf.nn.softmax(tf.matmul(L2, W3)+b3)

# #create a 1-level neural network
# W = tf.Variable(tf.truncated_normal([539, 2], stddev=0.1))
# # b = tf.Variable(tf.zeros([2]))
# b = tf.Variable(tf.zeros([2])+0.1)

# wx_b = tf.matmul(x, W)+b

#激活函数，实现非线性化
# prediction = tf.nn.relu(wx_b)
# prediction = tf.nn.tanh(wx_b)
# prediction = tf.nn.sigmoid(wx_b)
# prediction = tf.nn.softmax(wx_b)

loss = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits_v2(labels=y, logits=prediction))
# loss = tf.reduce_mean(tf.nn.sigmoid_cross_entropy_with_logits(labels=y, logits=prediction))

#train
train = tf.train.GradientDescentOptimizer(0.1).minimize(loss)

init = tf.global_variables_initializer()

#比较预测值与实际值
correct_pred = tf.equal(tf.argmax(y, 1), tf.argmax(prediction, 1)) #argmax 返回沿着某个维度最大值的位置

#准确率
accuracy = tf.reduce_mean(tf.cast(correct_pred, tf.float32))


# pred_one_hot = tf.stack(tf.argmin(prediction, 1), tf.argmax(prediction, 1))
# a = tf.argmin(prediction, 1)
# b = tf.argmax(prediction, 1)
# pred_one_hot = tf.transpose(tf.stack([a, b]))

pred_one_hot = tf.one_hot(tf.argmax(prediction, 1), 2)
# pred_one_hot = tf.one_hot(tf.argmax(prediction, 1), tf.shape(prediction)[0])
print(pred_one_hot)

y_sum = tf.reduce_sum(y, 0)

pred_sum = tf.reduce_sum(pred_one_hot, 0)

pred_int_one_hot = tf.one_hot(tf.argmax(prediction, 1), 2, off_value=2.0)
inter = tf.equal(y, pred_int_one_hot)
print(inter)

int_sum = tf.reduce_sum(tf.cast(inter, tf.int32), 0)

# correct_rej = tf.equal(tf.argmax(y, 1), tf.argmax(pred_one_hot, 1))
# int_rej_num = tf.reduce_sum(tf.cast(correct_rej, tf.int32))

# correct_app = tf.equal(tf.argmin(y, 1), tf.argmin(pred_one_hot, 1))
# int_app_num = tf.reduce_sum(tf.cast(correct_app, tf.int32))
# Out:
# Tensor("one_hot_3:0", shape=(?, 2), dtype=float32)
# Tensor("Equal_1:0", shape=(?, 2), dtype=bool)

# %%
with tf.Session() as sess:
    sess.run(init)
    
    # Start populating the filename queue.
    coord = tf.train.Coordinator()
    threads = tf.train.start_queue_runners(coord=coord)

    
    
    for step in range(1201):
        # Retrieve a single instance:
        batch_xs, batch_ys = sess.run([train_features, train_labels])
#         print(batch_xs.shape, batch_ys.shape)
#         print(batch_xs)
    
        sess.run(train, feed_dict={x: batch_xs, y: batch_ys})


        if step % 10 == 0:
            acc_train = sess.run(accuracy, feed_dict={x:batch_xs, y:batch_ys})
            
            test_xs, test_ys = sess.run([test_features, test_labels])
            pred, acc_test = sess.run([prediction, accuracy], feed_dict={x:test_xs, y:test_ys})
            print("step:" + str(step) + " train accurancy:" + str(acc_train) + "  test accurancy:" + str(acc_test))
            
            y_s, p_s, i_s = sess.run([y_sum, pred_sum, int_sum], feed_dict={x:batch_xs, y:batch_ys} )
            print("Train - Label sum:" + str(y_s) + " Prediction sum" + str(p_s) + " Correct sum:" + str(i_s))
        
            y_s, p_s, i_s = sess.run([y_sum, pred_sum, int_sum], feed_dict={x:test_xs, y:test_ys} )
            print("Test - Label sum:" + str(y_s) + " Prediction sum" + str(p_s) + " Correct sum:" + str(i_s))
            print("")
                  
    coord.request_stop()
    coord.join(threads)
# Out:
# step:0 train accurancy:0.51  test accurancy:0.46
# Train - Label sum:[100. 100.] Prediction sum[122.  78.] Correct sum:[62 40]
# Test - Label sum:[94.  6.] Prediction sum[48. 52.] Correct sum:[44  2]
#
# step:10 train accurancy:0.595  test accurancy:0.48
# Train - Label sum:[100. 100.] Prediction sum[115.  85.] Correct sum:[67 52]
# Test - Label sum:[91.  9.] Prediction sum[51. 49.] Correct sum:[45  3]
#
# step:20 train accurancy:0.54  test accurancy:0.47
# Train - Label sum:[100. 100.] Prediction sum[106.  94.] Correct sum:[57 51]
# Test - Label sum:[97.  3.] Prediction sum[48. 52.] Correct sum:[46  1]
#
# step:30 train accurancy:0.52  test accurancy:0.43
# Train - Label sum:[100. 100.] Prediction sum[110.  90.] Correct sum:[57 47]
# Test - Label sum:[91.  9.] Prediction sum[46. 54.] Correct sum:[40  3]
#
# step:40 train accurancy:0.495  test accurancy:0.45
# Train - Label sum:[100. 100.] Prediction sum[107.  93.] Correct sum:[53 46]
# Test - Label sum:[91.  9.] Prediction sum[44. 56.] Correct sum:[40  5]
#
# step:50 train accurancy:0.405  test accurancy:0.44
# Train - Label sum:[100. 100.] Prediction sum[111.  89.] Correct sum:[46 35]
# Test - Label sum:[94.  6.] Prediction sum[42. 58.] Correct sum:[40  4]
#
# step:60 train accurancy:0.49  test accurancy:0.45
# Train - Label sum:[100. 100.] Prediction sum[106.  94.] Correct sum:[52 46]
# Test - Label sum:[92.  8.] Prediction sum[41. 59.] Correct sum:[39  6]
#
# step:70 train accurancy:0.49  test accurancy:0.42
# Train - Label sum:[100. 100.] Prediction sum[104.  96.] Correct sum:[51 47]
# Test - Label sum:[95.  5.] Prediction sum[45. 55.] Correct sum:[41  1]
#
# step:80 train accurancy:0.465  test accurancy:0.42
# Train - Label sum:[100. 100.] Prediction sum[109.  91.] Correct sum:[51 42]
# Test - Label sum:[89. 11.] Prediction sum[47. 53.] Correct sum:[39  3]
#
# step:90 train accurancy:0.51  test accurancy:0.55
# Train - Label sum:[100. 100.] Prediction sum[100. 100.] Correct sum:[51 51]
# Test - Label sum:[87. 13.] Prediction sum[60. 40.] Correct sum:[51  4]
#
# step:100 train accurancy:0.455  test accurancy:0.45
# Train - Label sum:[100. 100.] Prediction sum[ 95. 105.] Correct sum:[43 48]
# Test - Label sum:[91.  9.] Prediction sum[46. 54.] Correct sum:[41  4]
#
# step:110 train accurancy:0.445  test accurancy:0.5
# Train - Label sum:[100. 100.] Prediction sum[109.  91.] Correct sum:[49 40]
# Test - Label sum:[90. 10.] Prediction sum[48. 52.] Correct sum:[44  6]
#
# step:120 train accurancy:0.49  test accurancy:0.47
# Train - Label sum:[100. 100.] Prediction sum[118.  82.] Correct sum:[58 40]
# Test - Label sum:[92.  8.] Prediction sum[49. 51.] Correct sum:[44  3]
#
# step:130 train accurancy:0.51  test accurancy:0.39
# Train - Label sum:[100. 100.] Prediction sum[102.  98.] Correct sum:[52 50]
# Test - Label sum:[92.  8.] Prediction sum[35. 65.] Correct sum:[33  6]
#
# step:140 train accurancy:0.51  test accurancy:0.49
# Train - Label sum:[100. 100.] Prediction sum[110.  90.] Correct sum:[56 46]
# Test - Label sum:[91.  9.] Prediction sum[52. 48.] Correct sum:[46  3]
#
# step:150 train accurancy:0.485  test accurancy:0.36
# Train - Label sum:[100. 100.] Prediction sum[ 99. 101.] Correct sum:[48 49]
# Test - Label sum:[95.  5.] Prediction sum[35. 65.] Correct sum:[33  3]
#
# step:160 train accurancy:0.565  test accurancy:0.35
# Train - Label sum:[100. 100.] Prediction sum[ 95. 105.] Correct sum:[54 59]
# Test - Label sum:[93.  7.] Prediction sum[30. 70.] Correct sum:[29  6]
#
# step:170 train accurancy:0.53  test accurancy:0.44
# Train - Label sum:[100. 100.] Prediction sum[ 96. 104.] Correct sum:[51 55]
# Test - Label sum:[96.  4.] Prediction sum[46. 54.] Correct sum:[43  1]
#
# step:180 train accurancy:0.54  test accurancy:0.38
# Train - Label sum:[100. 100.] Prediction sum[ 92. 108.] Correct sum:[50 58]
# Test - Label sum:[94.  6.] Prediction sum[34. 66.] Correct sum:[33  5]
#
# step:190 train accurancy:0.535  test accurancy:0.44
# Train - Label sum:[100. 100.] Prediction sum[107.  93.] Correct sum:[57 50]
# Test - Label sum:[92.  8.] Prediction sum[40. 60.] Correct sum:[38  6]
#
# step:200 train accurancy:0.48  test accurancy:0.51
# Train - Label sum:[100. 100.] Prediction sum[100. 100.] Correct sum:[48 48]
# Test - Label sum:[89. 11.] Prediction sum[42. 58.] Correct sum:[41 10]
#
# step:210 train accurancy:0.51  test accurancy:0.49
# Train - Label sum:[100. 100.] Prediction sum[ 88. 112.] Correct sum:[45 57]
# Test - Label sum:[91.  9.] Prediction sum[48. 52.] Correct sum:[44  5]
#
# step:220 train accurancy:0.405  test accurancy:0.4
# Train - Label sum:[100. 100.] Prediction sum[105.  95.] Correct sum:[43 38]
# Test - Label sum:[90. 10.] Prediction sum[40. 60.] Correct sum:[35  5]
#
# step:230 train accurancy:0.49  test accurancy:0.44
# Train - Label sum:[100. 100.] Prediction sum[116.  84.] Correct sum:[57 41]
# Test - Label sum:[94.  6.] Prediction sum[44. 56.] Correct sum:[41  3]
#
# step:240 train accurancy:0.485  test accurancy:0.43
# Train - Label sum:[100. 100.] Prediction sum[ 95. 105.] Correct sum:[46 51]
# Test - Label sum:[91.  9.] Prediction sum[40. 60.] Correct sum:[37  6]
#
# step:250 train accurancy:0.48  test accurancy:0.44
# Train - Label sum:[100. 100.] Prediction sum[100. 100.] Correct sum:[48 48]
# Test - Label sum:[90. 10.] Prediction sum[36. 64.] Correct sum:[35  9]
#
# step:260 train accurancy:0.495  test accurancy:0.42
# Train - Label sum:[100. 100.] Prediction sum[ 97. 103.] Correct sum:[48 51]
# Test - Label sum:[93.  7.] Prediction sum[43. 57.] Correct sum:[39  3]
#
# step:270 train accurancy:0.4  test accurancy:0.37
# Train - Label sum:[100. 100.] Prediction sum[ 96. 104.] Correct sum:[38 42]
# Test - Label sum:[92.  8.] Prediction sum[39. 61.] Correct sum:[34  3]
#
# step:280 train accurancy:0.49  test accurancy:0.4
# Train - Label sum:[100. 100.] Prediction sum[104.  96.] Correct sum:[51 47]
# Test - Label sum:[89. 11.] Prediction sum[39. 61.] Correct sum:[34  6]
#
# step:290 train accurancy:0.51  test accurancy:0.47
# Train - Label sum:[100. 100.] Prediction sum[ 98. 102.] Correct sum:[50 52]
# Test - Label sum:[96.  4.] Prediction sum[47. 53.] Correct sum:[45  2]
#
# step:300 train accurancy:0.42  test accurancy:0.39
# Train - Label sum:[100. 100.] Prediction sum[ 94. 106.] Correct sum:[39 45]
# Test - Label sum:[91.  9.] Prediction sum[40. 60.] Correct sum:[35  4]
#
# step:310 train accurancy:0.525  test accurancy:0.41
# Train - Label sum:[100. 100.] Prediction sum[ 95. 105.] Correct sum:[50 55]
# Test - Label sum:[89. 11.] Prediction sum[40. 60.] Correct sum:[35  6]
#
# step:320 train accurancy:0.47  test accurancy:0.54
# Train - Label sum:[100. 100.] Prediction sum[100. 100.] Correct sum:[47 47]
# Test - Label sum:[95.  5.] Prediction sum[53. 47.] Correct sum:[51  3]
#
# step:330 train accurancy:0.455  test accurancy:0.4
# Train - Label sum:[100. 100.] Prediction sum[103.  97.] Correct sum:[47 44]
# Test - Label sum:[90. 10.] Prediction sum[42. 58.] Correct sum:[36  4]
#
# step:340 train accurancy:0.465  test accurancy:0.53
# Train - Label sum:[100. 100.] Prediction sum[103.  97.] Correct sum:[48 45]
# Test - Label sum:[89. 11.] Prediction sum[50. 50.] Correct sum:[46  7]
#
# step:350 train accurancy:0.425  test accurancy:0.49
# Train - Label sum:[100. 100.] Prediction sum[109.  91.] Correct sum:[47 38]
# Test - Label sum:[95.  5.] Prediction sum[48. 52.] Correct sum:[46  3]
#
# step:360 train accurancy:0.505  test accurancy:0.39
# Train - Label sum:[100. 100.] Prediction sum[103.  97.] Correct sum:[52 49]
# Test - Label sum:[96.  4.] Prediction sum[41. 59.] Correct sum:[38  1]
#
# step:370 train accurancy:0.49  test accurancy:0.44
# Train - Label sum:[100. 100.] Prediction sum[ 96. 104.] Correct sum:[47 51]
# Test - Label sum:[92.  8.] Prediction sum[44. 56.] Correct sum:[40  4]
#
# step:380 train accurancy:0.46  test accurancy:0.35
# Train - Label sum:[100. 100.] Prediction sum[ 96. 104.] Correct sum:[44 48]
# Test - Label sum:[94.  6.] Prediction sum[37. 63.] Correct sum:[33  2]
#
# step:390 train accurancy:0.525  test accurancy:0.41
# Train - Label sum:[100. 100.] Prediction sum[103.  97.] Correct sum:[54 51]
# Test - Label sum:[90. 10.] Prediction sum[45. 55.] Correct sum:[38  3]
#
# step:400 train accurancy:0.465  test accurancy:0.5
# Train - Label sum:[100. 100.] Prediction sum[109.  91.] Correct sum:[51 42]
# Test - Label sum:[92.  8.] Prediction sum[50. 50.] Correct sum:[46  4]
#
# step:410 train accurancy:0.5  test accurancy:0.37
# Train - Label sum:[100. 100.] Prediction sum[ 96. 104.] Correct sum:[48 52]
# Test - Label sum:[86. 14.] Prediction sum[39. 61.] Correct sum:[31  6]
# step:420 train accurancy:0.45  test accurancy:0.33
# Train - Label sum:[100. 100.] Prediction sum[104.  96.] Correct sum:[47 43]
# Test - Label sum:[91.  9.] Prediction sum[34. 66.] Correct sum:[29  4]
#
# step:430 train accurancy:0.485  test accurancy:0.5
# Train - Label sum:[100. 100.] Prediction sum[101.  99.] Correct sum:[49 48]
# Test - Label sum:[92.  8.] Prediction sum[48. 52.] Correct sum:[45  5]
#
# step:440 train accurancy:0.63  test accurancy:0.46
# Train - Label sum:[100. 100.] Prediction sum[ 96. 104.] Correct sum:[61 65]
# Test - Label sum:[92.  8.] Prediction sum[38. 62.] Correct sum:[38  8]
#
# step:450 train accurancy:0.465  test accurancy:0.47
# Train - Label sum:[100. 100.] Prediction sum[101.  99.] Correct sum:[47 46]
# Test - Label sum:[96.  4.] Prediction sum[45. 55.] Correct sum:[44  3]
#
# step:460 train accurancy:0.46  test accurancy:0.45
# Train - Label sum:[100. 100.] Prediction sum[108.  92.] Correct sum:[50 42]
# Test - Label sum:[92.  8.] Prediction sum[41. 59.] Correct sum:[39  6]
#
# step:470 train accurancy:0.45  test accurancy:0.55
# Train - Label sum:[100. 100.] Prediction sum[110.  90.] Correct sum:[50 40]
# Test - Label sum:[91.  9.] Prediction sum[58. 42.] Correct sum:[52  3]
#
# step:480 train accurancy:0.46  test accurancy:0.43
# Train - Label sum:[100. 100.] Prediction sum[104.  96.] Correct sum:[48 44]
# Test - Label sum:[89. 11.] Prediction sum[48. 52.] Correct sum:[40  3]
#
# step:490 train accurancy:0.48  test accurancy:0.41
# Train - Label sum:[100. 100.] Prediction sum[100. 100.] Correct sum:[48 48]
# Test - Label sum:[88. 12.] Prediction sum[47. 53.] Correct sum:[38  3]
#
# step:500 train accurancy:0.44  test accurancy:0.44
# Train - Label sum:[100. 100.] Prediction sum[102.  98.] Correct sum:[45 43]
# Test - Label sum:[92.  8.] Prediction sum[38. 62.] Correct sum:[37  7]
#
# step:510 train accurancy:0.495  test accurancy:0.44
# Train - Label sum:[100. 100.] Prediction sum[107.  93.] Correct sum:[53 46]
# Test - Label sum:[93.  7.] Prediction sum[41. 59.] Correct sum:[39  5]
#
# step:520 train accurancy:0.455  test accurancy:0.42
# Train - Label sum:[100. 100.] Prediction sum[ 93. 107.] Correct sum:[42 49]
# Test - Label sum:[86. 14.] Prediction sum[40. 60.] Correct sum:[34  8]
#
# step:530 train accurancy:0.475  test accurancy:0.4
# Train - Label sum:[100. 100.] Prediction sum[101.  99.] Correct sum:[48 47]
# Test - Label sum:[90. 10.] Prediction sum[40. 60.] Correct sum:[35  5]
#
# step:540 train accurancy:0.57  test accurancy:0.47
# Train - Label sum:[100. 100.] Prediction sum[108.  92.] Correct sum:[61 53]
# Test - Label sum:[89. 11.] Prediction sum[46. 54.] Correct sum:[41  6]
#
# step:550 train accurancy:0.51  test accurancy:0.51
# Train - Label sum:[100. 100.] Prediction sum[108.  92.] Correct sum:[55 47]
# Test - Label sum:[95.  5.] Prediction sum[50. 50.] Correct sum:[48  3]
#
# step:560 train accurancy:0.495  test accurancy:0.44
# Train - Label sum:[100. 100.] Prediction sum[111.  89.] Correct sum:[55 44]
# Test - Label sum:[91.  9.] Prediction sum[41. 59.] Correct sum:[38  6]
#
# step:570 train accurancy:0.445  test accurancy:0.45
# Train - Label sum:[100. 100.] Prediction sum[113.  87.] Correct sum:[51 38]
# Test - Label sum:[91.  9.] Prediction sum[48. 52.] Correct sum:[42  3]
#
# step:580 train accurancy:0.475  test accurancy:0.43
# Train - Label sum:[100. 100.] Prediction sum[103.  97.] Correct sum:[49 46]
# Test - Label sum:[95.  5.] Prediction sum[44. 56.] Correct sum:[41  2]
#
# step:590 train accurancy:0.435  test accurancy:0.4
# Train - Label sum:[100. 100.] Prediction sum[103.  97.] Correct sum:[45 42]
# Test - Label sum:[88. 12.] Prediction sum[42. 58.] Correct sum:[35  5]
#
# step:600 train accurancy:0.515  test accurancy:0.27
# Train - Label sum:[100. 100.] Prediction sum[103.  97.] Correct sum:[53 50]
# Test - Label sum:[92.  8.] Prediction sum[31. 69.] Correct sum:[25  2]
#
# step:610 train accurancy:0.365  test accurancy:0.34
# Train - Label sum:[100. 100.] Prediction sum[111.  89.] Correct sum:[42 31]
# Test - Label sum:[90. 10.] Prediction sum[32. 68.] Correct sum:[28  6]
#
# step:620 train accurancy:0.43  test accurancy:0.38
# Train - Label sum:[100. 100.] Prediction sum[110.  90.] Correct sum:[48 38]
# Test - Label sum:[88. 12.] Prediction sum[42. 58.] Correct sum:[34  4]
#
# step:630 train accurancy:0.5  test accurancy:0.48
# Train - Label sum:[100. 100.] Prediction sum[104.  96.] Correct sum:[52 48]
# Test - Label sum:[91.  9.] Prediction sum[49. 51.] Correct sum:[44  4]
#
# step:640 train accurancy:0.515  test accurancy:0.4
# Train - Label sum:[100. 100.] Prediction sum[111.  89.] Correct sum:[57 46]
# Test - Label sum:[88. 12.] Prediction sum[38. 62.] Correct sum:[33  7]
#
# step:650 train accurancy:0.48  test accurancy:0.33
# Train - Label sum:[100. 100.] Prediction sum[102.  98.] Correct sum:[49 47]
# Test - Label sum:[94.  6.] Prediction sum[31. 69.] Correct sum:[29  4]
#
# step:660 train accurancy:0.49  test accurancy:0.42
# Train - Label sum:[100. 100.] Prediction sum[ 92. 108.] Correct sum:[45 53]
# Test - Label sum:[90. 10.] Prediction sum[44. 56.] Correct sum:[38  4]
#
# step:670 train accurancy:0.45  test accurancy:0.51
# Train - Label sum:[100. 100.] Prediction sum[108.  92.] Correct sum:[49 41]
# Test - Label sum:[94.  6.] Prediction sum[47. 53.] Correct sum:[46  5]
#
# step:680 train accurancy:0.425  test accurancy:0.41
# Train - Label sum:[100. 100.] Prediction sum[117.  83.] Correct sum:[51 34]
# Test - Label sum:[91.  9.] Prediction sum[44. 56.] Correct sum:[38  3]
#
# step:690 train accurancy:0.51  test accurancy:0.44
# Train - Label sum:[100. 100.] Prediction sum[108.  92.] Correct sum:[55 47]
# Test - Label sum:[90. 10.] Prediction sum[38. 62.] Correct sum:[36  8]
#
# step:700 train accurancy:0.505  test accurancy:0.51
# Train - Label sum:[100. 100.] Prediction sum[111.  89.] Correct sum:[56 45]
# Test - Label sum:[94.  6.] Prediction sum[49. 51.] Correct sum:[47  4]
#
# step:710 train accurancy:0.535  test accurancy:0.41
# Train - Label sum:[100. 100.] Prediction sum[105.  95.] Correct sum:[56 51]
# Test - Label sum:[92.  8.] Prediction sum[41. 59.] Correct sum:[37  4]
#
# step:720 train accurancy:0.46  test accurancy:0.46
# Train - Label sum:[100. 100.] Prediction sum[110.  90.] Correct sum:[51 41]
# Test - Label sum:[96.  4.] Prediction sum[46. 54.] Correct sum:[44  2]
#
# step:730 train accurancy:0.505  test accurancy:0.38
# Train - Label sum:[100. 100.] Prediction sum[123.  77.] Correct sum:[62 39]
# Test - Label sum:[90. 10.] Prediction sum[36. 64.] Correct sum:[32  6]
#
# step:740 train accurancy:0.505  test accurancy:0.38
# Train - Label sum:[100. 100.] Prediction sum[125.  75.] Correct sum:[63 38]
# Test - Label sum:[92.  8.] Prediction sum[36. 64.] Correct sum:[33  5]
#
# step:750 train accurancy:0.485  test accurancy:0.42
# Train - Label sum:[100. 100.] Prediction sum[111.  89.] Correct sum:[54 43]
# Test - Label sum:[94.  6.] Prediction sum[42. 58.] Correct sum:[39  3]
#
# step:760 train accurancy:0.59  test accurancy:0.46
# Train - Label sum:[100. 100.] Prediction sum[ 94. 106.] Correct sum:[56 62]
# Test - Label sum:[95.  5.] Prediction sum[43. 57.] Correct sum:[42  4]
#
# step:770 train accurancy:0.45  test accurancy:0.41
# Train - Label sum:[100. 100.] Prediction sum[112.  88.] Correct sum:[51 39]
# Test - Label sum:[94.  6.] Prediction sum[45. 55.] Correct sum:[40  1]
#
# step:780 train accurancy:0.52  test accurancy:0.5
# Train - Label sum:[100. 100.] Prediction sum[124.  76.] Correct sum:[64 40]
# Test - Label sum:[93.  7.] Prediction sum[51. 49.] Correct sum:[47  3]
#
# step:790 train accurancy:0.55  test accurancy:0.31
# Train - Label sum:[100. 100.] Prediction sum[108.  92.] Correct sum:[59 51]
# Test - Label sum:[92.  8.] Prediction sum[33. 67.] Correct sum:[28  3]
#
# step:800 train accurancy:0.545  test accurancy:0.53
# Train - Label sum:[100. 100.] Prediction sum[113.  87.] Correct sum:[61 48]
# Test - Label sum:[95.  5.] Prediction sum[50. 50.] Correct sum:[49  4]
#
# step:810 train accurancy:0.47  test accurancy:0.47
# Train - Label sum:[100. 100.] Prediction sum[ 96. 104.] Correct sum:[45 49]
# Test - Label sum:[96.  4.] Prediction sum[47. 53.] Correct sum:[45  2]
#
# step:820 train accurancy:0.445  test accurancy:0.48
# Train - Label sum:[100. 100.] Prediction sum[103.  97.] Correct sum:[46 43]
# Test - Label sum:[93.  7.] Prediction sum[45. 55.] Correct sum:[43  5]
#
# step:830 train accurancy:0.49  test accurancy:0.5
# Train - Label sum:[100. 100.] Prediction sum[ 98. 102.] Correct sum:[48 50]
# Test - Label sum:[86. 14.] Prediction sum[46. 54.] Correct sum:[41  9]
# step:840 train accurancy:0.48  test accurancy:0.49
# Train - Label sum:[100. 100.] Prediction sum[110.  90.] Correct sum:[53 43]
# Test - Label sum:[88. 12.] Prediction sum[47. 53.] Correct sum:[42  7]
#
# step:850 train accurancy:0.515  test accurancy:0.4
# Train - Label sum:[100. 100.] Prediction sum[103.  97.] Correct sum:[53 50]
# Test - Label sum:[90. 10.] Prediction sum[42. 58.] Correct sum:[36  4]
#
# step:860 train accurancy:0.485  test accurancy:0.48
# Train - Label sum:[100. 100.] Prediction sum[101.  99.] Correct sum:[49 48]
# Test - Label sum:[94.  6.] Prediction sum[46. 54.] Correct sum:[44  4]
#
# step:870 train accurancy:0.485  test accurancy:0.48
# Train - Label sum:[100. 100.] Prediction sum[ 93. 107.] Correct sum:[45 52]
# Test - Label sum:[90. 10.] Prediction sum[48. 52.] Correct sum:[43  5]
#
# step:880 train accurancy:0.515  test accurancy:0.42
# Train - Label sum:[100. 100.] Prediction sum[ 95. 105.] Correct sum:[49 54]
# Test - Label sum:[89. 11.] Prediction sum[45. 55.] Correct sum:[38  4]
#
# step:890 train accurancy:0.54  test accurancy:0.49
# Train - Label sum:[100. 100.] Prediction sum[116.  84.] Correct sum:[62 46]
# Test - Label sum:[94.  6.] Prediction sum[47. 53.] Correct sum:[45  4]
#
# step:900 train accurancy:0.445  test accurancy:0.4
# Train - Label sum:[100. 100.] Prediction sum[ 95. 105.] Correct sum:[42 47]
# Test - Label sum:[90. 10.] Prediction sum[40. 60.] Correct sum:[35  5]
#
# step:910 train accurancy:0.515  test accurancy:0.38
# Train - Label sum:[100. 100.] Prediction sum[107.  93.] Correct sum:[55 48]
# Test - Label sum:[92.  8.] Prediction sum[40. 60.] Correct sum:[35  3]
#
# step:920 train accurancy:0.425  test accurancy:0.38
# Train - Label sum:[100. 100.] Prediction sum[103.  97.] Correct sum:[44 41]
# Test - Label sum:[94.  6.] Prediction sum[36. 64.] Correct sum:[34  4]
#
# step:930 train accurancy:0.505  test accurancy:0.49
# Train - Label sum:[100. 100.] Prediction sum[103.  97.] Correct sum:[52 49]
# Test - Label sum:[93.  7.] Prediction sum[48. 52.] Correct sum:[45  4]
#
# step:940 train accurancy:0.485  test accurancy:0.45
# Train - Label sum:[100. 100.] Prediction sum[117.  83.] Correct sum:[57 40]
# Test - Label sum:[91.  9.] Prediction sum[44. 56.] Correct sum:[40  5]
#
# step:950 train accurancy:0.455  test accurancy:0.44
# Train - Label sum:[100. 100.] Prediction sum[ 97. 103.] Correct sum:[44 47]
# Test - Label sum:[94.  6.] Prediction sum[42. 58.] Correct sum:[40  4]
#
# step:960 train accurancy:0.435  test accurancy:0.42
# Train - Label sum:[100. 100.] Prediction sum[115.  85.] Correct sum:[51 36]
# Test - Label sum:[90. 10.] Prediction sum[40. 60.] Correct sum:[36  6]
#
# step:970 train accurancy:0.5  test accurancy:0.36
# Train - Label sum:[100. 100.] Prediction sum[108.  92.] Correct sum:[54 46]
# Test - Label sum:[92.  8.] Prediction sum[36. 64.] Correct sum:[32  4]
#
# step:980 train accurancy:0.47  test accurancy:0.39
# Train - Label sum:[100. 100.] Prediction sum[104.  96.] Correct sum:[49 45]
# Test - Label sum:[87. 13.] Prediction sum[42. 58.] Correct sum:[34  5]
#
# step:990 train accurancy:0.465  test accurancy:0.38
# Train - Label sum:[100. 100.] Prediction sum[101.  99.] Correct sum:[47 46]
# Test - Label sum:[87. 13.] Prediction sum[39. 61.] Correct sum:[32  6]
#
# step:1000 train accurancy:0.445  test accurancy:0.54
# Train - Label sum:[100. 100.] Prediction sum[109.  91.] Correct sum:[49 40]
# Test - Label sum:[84. 16.] Prediction sum[52. 48.] Correct sum:[45  9]
#
# step:1010 train accurancy:0.47  test accurancy:0.43
# Train - Label sum:[100. 100.] Prediction sum[ 94. 106.] Correct sum:[44 50]
# Test - Label sum:[97.  3.] Prediction sum[44. 56.] Correct sum:[42  1]
#
# step:1020 train accurancy:0.525  test accurancy:0.45
# Train - Label sum:[100. 100.] Prediction sum[101.  99.] Correct sum:[53 52]
# Test - Label sum:[95.  5.] Prediction sum[44. 56.] Correct sum:[42  3]
#
# step:1030 train accurancy:0.435  test accurancy:0.38
# Train - Label sum:[100. 100.] Prediction sum[101.  99.] Correct sum:[44 43]
# Test - Label sum:[90. 10.] Prediction sum[30. 70.] Correct sum:[29  9]
#
# step:1040 train accurancy:0.455  test accurancy:0.38
# Train - Label sum:[100. 100.] Prediction sum[105.  95.] Correct sum:[48 43]
# Test - Label sum:[95.  5.] Prediction sum[39. 61.] Correct sum:[36  2]
#
# step:1050 train accurancy:0.475  test accurancy:0.4
# Train - Label sum:[100. 100.] Prediction sum[ 93. 107.] Correct sum:[44 51]
# Test - Label sum:[93.  7.] Prediction sum[41. 59.] Correct sum:[37  3]
#
# step:1060 train accurancy:0.515  test accurancy:0.39
# Train - Label sum:[100. 100.] Prediction sum[ 97. 103.] Correct sum:[50 53]
# Test - Label sum:[92.  8.] Prediction sum[39. 61.] Correct sum:[35  4]
#
# step:1070 train accurancy:0.51  test accurancy:0.5
# Train - Label sum:[100. 100.] Prediction sum[ 94. 106.] Correct sum:[48 54]
# Test - Label sum:[90. 10.] Prediction sum[44. 56.] Correct sum:[42  8]
#
# step:1080 train accurancy:0.485  test accurancy:0.42
# Train - Label sum:[100. 100.] Prediction sum[ 99. 101.] Correct sum:[48 49]
# Test - Label sum:[89. 11.] Prediction sum[37. 63.] Correct sum:[34  8]
#
# step:1090 train accurancy:0.47  test accurancy:0.49
# Train - Label sum:[100. 100.] Prediction sum[104.  96.] Correct sum:[49 45]
# Test - Label sum:[90. 10.] Prediction sum[45. 55.] Correct sum:[42  7]
#
# step:1100 train accurancy:0.465  test accurancy:0.39
# Train - Label sum:[100. 100.] Prediction sum[ 93. 107.] Correct sum:[43 50]
# Test - Label sum:[94.  6.] Prediction sum[35. 65.] Correct sum:[34  5]
#
# step:1110 train accurancy:0.465  test accurancy:0.36
# Train - Label sum:[100. 100.] Prediction sum[ 99. 101.] Correct sum:[46 47]
# Test - Label sum:[97.  3.] Prediction sum[37. 63.] Correct sum:[35  1]
#
# step:1120 train accurancy:0.44  test accurancy:0.38
# Train - Label sum:[100. 100.] Prediction sum[106.  94.] Correct sum:[47 41]
# Test - Label sum:[95.  5.] Prediction sum[37. 63.] Correct sum:[35  3]
#
# step:1130 train accurancy:0.53  test accurancy:0.53
# Train - Label sum:[100. 100.] Prediction sum[102.  98.] Correct sum:[54 52]
# Test - Label sum:[90. 10.] Prediction sum[49. 51.] Correct sum:[46  7]
#
# step:1140 train accurancy:0.48  test accurancy:0.35
# Train - Label sum:[100. 100.] Prediction sum[102.  98.] Correct sum:[49 47]
# Test - Label sum:[92.  8.] Prediction sum[35. 65.] Correct sum:[31  4]
#
# step:1150 train accurancy:0.49  test accurancy:0.51
# Train - Label sum:[100. 100.] Prediction sum[102.  98.] Correct sum:[50 48]
# Test - Label sum:[89. 11.] Prediction sum[50. 50.] Correct sum:[45  6]
#
# step:1160 train accurancy:0.515  test accurancy:0.48
# Train - Label sum:[100. 100.] Prediction sum[ 93. 107.] Correct sum:[48 55]
# Test - Label sum:[92.  8.] Prediction sum[46. 54.] Correct sum:[43  5]
#
# step:1170 train accurancy:0.48  test accurancy:0.44
# Train - Label sum:[100. 100.] Prediction sum[104.  96.] Correct sum:[50 46]
# Test - Label sum:[94.  6.] Prediction sum[46. 54.] Correct sum:[42  2]
#
# step:1180 train accurancy:0.465  test accurancy:0.41
# Train - Label sum:[100. 100.] Prediction sum[ 99. 101.] Correct sum:[46 47]
# Test - Label sum:[95.  5.] Prediction sum[44. 56.] Correct sum:[40  1]
#
# step:1190 train accurancy:0.52  test accurancy:0.51
# Train - Label sum:[100. 100.] Prediction sum[ 92. 108.] Correct sum:[48 56]
# Test - Label sum:[95.  5.] Prediction sum[52. 48.] Correct sum:[49  2]
#
# step:1200 train accurancy:0.445  test accurancy:0.45
# Train - Label sum:[100. 100.] Prediction sum[101.  99.] Correct sum:[45 44]
# Test - Label sum:[92.  8.] Prediction sum[39. 61.] Correct sum:[38  7]
